# %% [markdown]
# ### data generate

# %%
def slot():
    hello = ['안녕하세요.',
                '주문할게요.',
                '주문이요.',
                '저기요.',
                '여기요.',
                '여기 주문할게요.',
                '저 주문하려고 하는데요.']
    beverage = ['돌체 콜드 브루',
                '바닐라 크림 콜드 브루',
                '콜드 브루',
                '콜드 브루 오트 라떼',
                '오늘의 커피',
                '에스프레소 콘 파나',
                '에스프레소 마키아또',
                '카페 아메리카노',
                '카라멜 마키아또',
                '카푸치노',
                '스타벅스 돌체 라떼',
                '카페 라떼',
                '카페 모카',
                '화이트 초콜릿 모카',
                '바닐라 플랫 화이트',
                '바닐라 스타벅스 더블 샷',
                '에스프레소',
                '커피 스타벅스 더블 샷',
                '클래식 아포가토',
                '헤이즐넛 스타벅스 더블 샷',
                '더블 에스프레소 칩 프라푸치노',
                '모카 프라푸치노',
                '에스프레소 프라푸치노',
                '자바 칩 프라푸치노',
                '카라멜 프라푸치노',
                '화이트 초콜릿 모카 프라푸치노',
                '바닐라 크림 프라푸치노',
                '제주 유기농 말차로 만든 크림 프라푸치노',
                '초콜릿 크림 칩 프라푸치노',
                '망고 패션 프루트 블렌디드',
                '딸기 딜라이트 요거트 블렌디드',
                '망고 바나나 블렌디드',
                '민트 초콜릿 칩 블렌디드',
                '피치 레몬 블렌디드',
                '블랙 티 레모네이드 피지오',
                '쿨 라임 피지오',
                '패션 탱고 티 레모네이드 피지오',
                '라임 패션 티',
                '민트 블렌드 티',
                '얼 그레이 티',
                '유스베리 티',
                '유자 민트 티',
                '잉글리쉬 브렉퍼스트 티',
                '자몽 허니 블랙 티',
                '제주 유기 녹차',
                '캐모마일 블렌드 티',
                '패션 프루트 티',
                '히비스커스 블렌드 티',
                '돌체 블랙 밀크 티',
                '제주 유기농 말차로 만든 라떼',
                '차이 티 라떼',
                '시그니처 핫 초콜릿',
                '스팀 우유',
                '우유']
    temperature = ['따뜻한', '뜨거운', 'hot', '차가운', '시원한','시원하게', 'ice', '아이스', 'cool', '따뜻하게', '차갑게']
    size = ['short','tall','venti','숏','톨','벤티']
    quantity = ['한 잔','두 잔','세 잔','네 잔','다섯 잔','여섯 잔','일곱 잔','여덟 잔','아홉 잔','열 잔','하나','둘','셋','넷','다섯','여섯','일곱','여덟','아홉','1 잔','2 잔','3 잔','4 잔','5 잔','6 잔','7 잔','8 잔','9 잔','10 잔']
    syrup = ['바닐라 시럽', '헤이즐넛 시럽', '카라멜 시럽', '클래식 시럽', '모카 시럽', '화이트 모카', '돌체 시럽']
    syrup_quantity = ['한 번','두 번','세 번','네 번','다섯 번','여섯 번','일곱 번','여덟 번','아홉 번','열 번','한 펌프','두 펌프','세 펌프','다섯 펌프','여섯 펌프','일곱 펌프','여덟 펌프','아홉 펌프','열 펌프','1 번','2 번','3 번','4 번','5 번','6 번','7 번','8 번','9 번','10 번','1 펌프','2 펌프','3 펌프','4 펌프','5 펌프','6 펌프','7 펌프','8 펌프','9 펌프','10 펌프']
    food = ['한 입에 쏙 치즈 꿀 볼',
                '자일리톨 캔디 크리스탈 민트',
                '세븐 레이어 가나슈 케이크',
                '할로윈 버터 마들렌',
                '쿠키 블루베리 잼 머핀',
                '씨프렌즈 캔디',
                '플랜트 햄 루꼴라 샌드위치',
                '번트 치즈 케이크',
                '밀크 푸딩',
                '초콜릿 아포가토',
                '크랜베리 치킨 치즈 샌드위치',
                '리프 파이',
                '리코타 치즈 바게트 샌드위치',
                '큐브 라이스 카스텔라',
                '진한 초콜릿 크레이프 케이크',
                '할로윈 초콜릿 마들렌',
                '자바 칩 바닐라 아포가토',
                '리얼 블루베리 베이글',
                '연유 밀크모닝',
                '햄 루꼴라 올리브 샌드위치',
                '카라멜 와플',
                '플랜트 함박 파스타 밀 박스',
                '자바 칩 유기농 아이스크림 초콜릿',
                '초콜릿 롤링 크루아상',
                'B.C.L.T. 샌드위치 밀 박스',
                '클래식 스콘',
                '화이트 초콜릿 카우보이 쿠키',
                '리저브 초콜릿 세트',
                '밤콩달콩 두유 브레드',
                '포테이통통 샌드위치',
                '유기농 아이스크림 초콜릿',
                '마스카포네 티라미수 케이크',
                '호두 당근 케이크',
                '라즈베리 쇼콜라',
                '상큼한 샤인 머스캣 스윗박스',
                '초콜릿 월넛 돔 쿠키',
                '오도독 건강한 넛 블루베리',
                '자일리톨 캔디 크리스탈 레몬',
                '매콤 소시지 불고기 베이크',
                '오가닉 프로틴 그릭 요거트 & 그래놀라',
                '자바 칩 초콜릿 아포가토',
                '트러플 머쉬룸 수프',
                '단호박 에그 샌드위치',
                '리얼 치즈 베이글',
                '가나슈 품은 초콜릿 스콘',
                '촉촉 초콜릿 생크림 케이크',
                '블루베리 마카롱',
                '청크 초콜릿 쿠키 틴 세트',
                '크림치즈 브리오슈 보스톡',
                '우리쌀 카스텔라',
                '콜라겐 레드푸드 쉐이크',
                '크레이프 에멘탈 치즈 케이크',
                '우유 품은 초콜릿 크루아상',
                '로고 코인 밀크 초콜릿 실버',
                '하루 한 컵 RED',
                '한 입에 쏙 우리 과일칩 딸기',
                '한 입에 쏙 우리 과일칩 사과',
                '로스티드 아몬드 앤 초콜릿',
                '다크 초콜릿 카우보이 쿠키',
                '현미 크림 수프',
                '한입에 쏙 공주 알밤',
                '부드러운 생크림 카스텔라',
                '바비큐 치킨 치즈 치아바타',
                '로고 코인 다크 초콜릿 골드',
                '사과 가득 핸디 젤리',
                '할로윈 베어리 위치 카라멜',
                '담백한 플레인 베이글',
                '진한 초콜릿 퍼지 케이크',
                '베어리스타 오가닉 젤리',
                '쉬림프 코코넛 샐러드 밀 박스',
                '트리플 미니 스콘',
                '에그에그 샌드위치',
                '더블 치즈 베이글 칩',
                '헤븐리 티라미수',
                '아몬드 토피넛 캔디',
                '피칸 브라우니',
                '우리 흑미 카스텔라',
                '다크 초콜릿 마카롱',
                '커리 치킨 샐러드 밀 박스',
                '레드벨벳 크림치즈 케이크',
                '할로윈 치즈 마카롱',
                '유산균 옐로푸드 쉐이크',
                '스모크드 소시지 브레드',
                '클라우드 치즈 케이크',
                '한라봉 가득 핸디 젤리',
                '트리플 치즈 크로크무슈',
                '자바 칩 유기농 아이스크림 바닐라',
                '에그 베이컨 브리오슈 밀 박스',
                '할로윈 민트 초콜릿 케이크',
                '바닐라 마카롱',
                '유기농 아이스크림 바닐라',
                '넛츠 초콜릿 아포가토',
                'B.E.L.T. 샌드위치',
                '오렌지 카라멜 데니핀',
                '스트로베리 마카롱',
                '할로윈 흑임자 마카롱',
                '브렉퍼스트 잉글리쉬 머핀',
                '청담스타 오 허니 케이크',
                '하트 파이',
                '가나슈 케이크',
                '올라 쿠바노 샌드위치',
                '라이스 칩 블루베리 잼',
                '바질 토마토 크림치즈 베이글',
                '촉촉 슈크림 레이어 케이크',
                '미니 클래식 스콘',
                '프로틴 블랙푸드 쉐이크 ',
                '베이컨 치즈 토스트',
                '블루베리 쿠키 치즈 케이크',
                '몽블랑 치즈 케이크',
                '감바스 파스타 밀 박스',
                '한 입에 쏙 고구마',
                '뺑 오 쇼콜라',
                '스타벅스 찹쌀말랑',
                '할로윈 베어리 펌킨 카라멜',
                '슈크림 가득 바움쿠헨',
                '청담스타 얼 그레이 밀크 케이크',
                '바닐라 아포가토',
                '초콜릿 푸딩',
                '상큼한 딸기 생크림 카스텔라',
                '오가닉 그릭 요거트 플레인',
                '할로윈 펌킨 치즈 케이크',
                '부드러운 티라미수 롤',
                '넛츠 바닐라 아포가토',
                '헤이즐넛 브라우니']
    food_quantity = ['한 개','두 개','세 개','다섯 개','여섯 개','일곱 개','여덟 개','아홉 개','열 개','하나','둘','셋','넷','다섯','여섯','일곱','여덟','아홉','1 개','2 개','3 개','4 개','5 개','6 개','7 개','8 개','9 개','10 개']

    return hello, beverage, temperature, size, quantity, syrup, syrup_quantity, food, food_quantity

def data_maker():

    import random
    
    default =  ['매장 오픈시간이 어떻게 되나요?',
                '오픈시간 알려주세요.',
                '마감시간이 어떻게 되나요?',
                '마감시간 알려주세요.',
                '언제 마감인가요?',
                '여기 화장실이 어디에요?',
                '매장 전화번호 좀 알려주세요.',
                '주차 가능한가요?',
                '와이파이 비밀번호가 뭔가요?']
    data_1 = []
    append_1 = data_1.append
    # data_2 = []
    # append_2 = data_2.append
    # data_3 = []
    # append_3 = data_3.append

    hello, beverage, temperature, size, quantity, syrup, syrup_quantity, food, food_quantity = slot()

    for i in range(2500):
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/사이즈 /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/ 넣어주시고 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/ 주세요.')
        default.append(f'/temperature;{random.choice(temperature)}/ /beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/ /size;{random.choice(size)}/로 주시고요 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/ /food;{random.choice(food)}/도 /food_quantity;{random.choice(food_quantity)}/ 주세요.')
        default.append(f'{random.choice(hello)} /temperature;{random.choice(temperature)}/ /beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/사이즈 /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/ 넣어주시고 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/ 주세요.')
        default.append(f'{random.choice(hello)} /beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /quantity;{random.choice(quantity)}/ /size;{random.choice(size)}/로 주시고요 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/ /food;{random.choice(food)}/도 /food_quantity;{random.choice(food_quantity)}/ 주세요.')
        default.append(f'/beverage;{random.choice(beverage)}/주세요')
        default.append(f'/food;{random.choice(food)}/이요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/ 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/에 /food;{random.choice(food)}/도 주세요')
        default.append(f'/food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/ 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /quantity;{random.choice(quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/')
        default.append(f'/beverage;{random.choice(beverage)}/에 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /quantity;{random.choice(quantity)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ 넣어주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/에 /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/랑 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /quantity;{random.choice(quantity)}/랑 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/에 /syrup;{random.choice(syrup)}/ /syrup_quantity;{random.choice(syrup_quantity)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/랑 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/랑 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/랑 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/에 /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
        default.append(f'/beverage;{random.choice(beverage)}/ /temperature;{random.choice(temperature)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/도 주세요')
        default.append(f'/beverage;{random.choice(beverage)}/ /size;{random.choice(size)}/ /quantity;{random.choice(quantity)}/에 /syrup;{random.choice(syrup)}/넣고 /food;{random.choice(food)}/ /food_quantity;{random.choice(food_quantity)}/요')
                
    
    for bev in beverage:
        append_1(f'/beverage;{bev}/ 주세요.')
        append_1(f'/beverage;{bev}/로 주세요.')
        append_1(f'/beverage;{bev}/ 부탁합니다.')
        append_1(f'/beverage;{bev}/로 부탁합니다.')

    for qty in quantity:
        append_1(f'/quantity;{qty}/ 주세요')
        append_1(f'/quantity;{qty}/요')

    for siz in size:
        append_1(f'/size;{siz}/로 주세요.')
        append_1(f'/size;{siz}/요.')
        append_1(f'/size;{siz}/로 부탁합니다.')
        append_1(f'/size;{siz}/로 할게요.')

    for sy in syrup:
        append_1(f'/syrup;{sy}/ 넣어주세요.')
        append_1(f'/syrup;{sy}/ 부탁합니다.')

    for fo in food:
        append_1(f'/food;{fo}/ 주세요.')
        append_1(f'/food;{fo}/로 주세요.')
        append_1(f'/food;{fo}/ 부탁합니다.')

    

    default.extend(data_1)
    
    
    return default

# %%
len(data_maker())
# Out:
# 113193

# %% [markdown]
# ### Save to txt file

# %%
import itertools
with open('data.txt','a') as f:
    for i in data_maker():
        f.write(f'{i}\n')
