# %% [markdown]
# ### data generate

# %%
def slot():
    beverage = ['나이트로 바닐라 크림',
                '나이트로 콜드 브루',
                '돌체 콜드 브루',
                '바닐라 크림 콜드 브루',
                '벨벳 다크 모카 나이트로',
                '시그니처 더 블랙 콜드 브루',
                '제주 비자림 콜드 브루',
                '콜드 브루',
                '콜드 브루 몰트',
                '콜드 브루 오트 라떼',
                '콜드 브루 플로트',
                '프렌치 애플 타르트 나이트로',
                '아이스 커피',
                '오늘의 커피',
                '아이스 펌킨 스파이스 라떼',
                '펌킨 스파이스 라떼',
                '에스프레소 콘 파나',
                '에스프레소 마키아또',
                '아이스 카페 아메리카노',
                '카페 아메리카노',
                '아이스 카라멜 마키아또',
                '카라멜 마키아또',
                '아이스 카푸치노',
                '카푸치노',
                '라벤더 카페 브레베',
                '럼 샷 코르타도',
                '바닐라 빈 라떼',
                '블론드 에스프레소 라떼',
                '사케라또 비안코 오버 아이스',
                '스타벅스 돌체 라떼',
                '아이스 라벤더 카페 브레베',
                '아이스 바닐라 빈 라떼',
                '아이스 블론드 에스프레소 라떼',
                '아이스 스타벅스 돌체 라떼',
                '아이스 카페 라떼',
                '카페 라떼',
                '아이스 카페 모카',
                '아이스 화이트 초콜릿 모카',
                '카페 모카',
                '화이트 초콜릿 모카',
                '바닐라 플랫 화이트',
                '바닐라 스타벅스 더블 샷',
                '블론드 바닐라 더블 샷 마키아또',
                '사케라또 아포가토',
                '스파클링 시트러스 에스프레소',
                '아이스 블론드 바닐라 더블 샷 마키아또',
                '에스프레소',
                '커피 스타벅스 더블 샷',
                '클래식 아포가토',
                '헤이즐넛 스타벅스 더블 샷',
                '바닐라 미라 크림 프라푸치노',
                '더블 에스프레소 칩 프라푸치노',
                '모카 프라푸치노',
                '에스프레소 프라푸치노',
                '자바 칩 프라푸치노',
                '카라멜 프라푸치노',
                '화이트 초콜릿 모카 프라푸치노',
                '바닐라 크림 프라푸치노',
                '제주 까망 크림 프라푸치노',
                '제주 쑥떡 크림 프라푸치노',
                '제주 유기농 말차로 만든 크림 프라푸치노',
                '초콜릿 크림 칩 프라푸치노',
                '화이트 타이거 프라푸치노',
                '망고 패션 프루트 블렌디드',
                '딸기 딜라이트 요거트 블렌디드',
                '망고 바나나 블렌디드',
                '민트 초콜릿 칩 블렌디드',
                '피치 & 레몬 블렌디드',
                '블랙 티 레모네이드 피지오',
                '쿨 라임 피지오',
                '패션 탱고 티 레모네이드 피지오',
                '라임 패션 티',
                '민트 블렌드 티',
                '별궁 오미자 유스베리 티',
                '아이스 라임 패션 티',
                '아이스 민트 블렌드 티',
                '아이스 얼 그레이 티',
                '아이스 유스베리 티',
                '아이스 유자 민트 티',
                '아이스 잉글리쉬 브렉퍼스트 티',
                '아이스 제주 유기 녹차',
                '아이스 캐모마일 블렌드 티',
                '아이스 히비스커스 블렌드 티',
                '얼 그레이 티',
                '유스베리 티',
                '유자 민트 티',
                '잉글리쉬 브렉퍼스트 티',
                '자몽 허니 블랙 티',
                '제주 유기 녹차',
                '캐모마일 블렌드 티',
                '패션 프루트 티',
                '히비스커스 블렌드 티',
                '아이스 별궁 오미자 유스베리 티',
                '아이스 자몽 허니 블랙 티',
                '아이스 제주 카멜리아 티 ',
                '아이스 패션 프루트 티',
                '아이스 푸를 청귤 민트 티',
                '제주 카멜리아 티 ',
                '돌체 블랙 밀크 티',
                '아이스 돌체 블랙 밀크 티',
                '아이스 제주 유기농 말차로 만든 라떼',
                '아이스 차이 티 라떼',
                '아이스 콩고물 블랙 밀크 티',
                '제주 유기농 말차로 만든 라떼',
                '차이 티 라떼',
                '콩고물 블랙 밀크 티',
                '아이스 젠틀 조커 스윗 사워',
                '시그니처 핫 초콜릿',
                '아이스 시그니처 초콜릿',
                '플러피 판다 아이스 초콜릿',
                '플러피 판다 핫 초콜릿',
                '라임 플로터 위드 리저브 CB 샷',
                '스타벅스 슬래머',
                '스팀 우유',
                '아이스 제주 까망 라떼',
                '오렌지 플로터 위드 리저브 CB 샷',
                '우유',
                '제주 까망 라떼',
                '제주 스노잉 백록담',
                '제주 쑥쑥 라떼',
                '기운내라임 190ML',
                '파이팅 청귤 190ML',
                '한방에 쭉 감당 190ML',
                '도와줘 흑흑 190ML',
                '딸기주스 190ML',
                '망고주스 190ML',
                '스타 루비 자몽 스위트',
                '유기농 오렌지 100% 주스',
                '케일&사과주스 190ML',
                '토마토주스 190ML',
                '퍼플베리 굿 190ML',
                '핑크 용과 레모네이드 ',
                '한라봉주스 190ML',
                '햇사과 주스 190ML',
                '딸기 가득 요거트',
                '블루베리 요거트 190ML',
                '치아씨드 요거트 190ML']
    size = ['short','tall','venti','숏','톨','벤티']
    syrup = ['바닐라 시럽', '헤이즐넛 시럽', '카라멜 시럽', '클래식 시럽', '모카 시럽', '화이트 모카', '돌체 시럽']
    food = ['한 입에 쏙 치즈 꿀 볼',
                '자일리톨 캔디 크리스탈 민트',
                '세븐 레이어 가나슈 케이크',
                '할로윈 버터 마들렌',
                '쿠키 블루베리 잼 머핀',
                '씨프렌즈 캔디',
                '플랜트 햄&루꼴라 샌드위치',
                '번트 치즈 케이크',
                'New 밀크 푸딩',
                '초콜릿 아포가토',
                '크랜베리 치킨 치즈 샌드위치',
                '리프 파이',
                '리코타 치즈 바게트 샌드위치',
                '큐브 라이스 카스텔라',
                '진한 초콜릿 크레이프 케이크',
                '할로윈 초콜릿 마들렌',
                '자바 칩 바닐라 아포가토',
                '리얼 블루베리 베이글',
                '연유 밀크모닝',
                '햄&루꼴라 올리브 샌드위치',
                '카라멜 와플',
                '플랜트 함박&파스타 밀 박스',
                '자바 칩 유기농 아이스크림 초콜릿',
                '초콜릿 롤링 크루아상',
                'B.C.L.T. 샌드위치 밀 박스',
                '클래식 스콘',
                '화이트 초콜릿 카우보이 쿠키',
                '리저브 초콜릿 세트',
                '밤콩달콩 두유 브레드',
                '포테이통통 샌드위치',
                '유기농 아이스크림 초콜릿',
                '마스카포네 티라미수 케이크',
                '호두 당근 케이크',
                '라즈베리 쇼콜라',
                '상큼한 샤인 머스캣 스윗박스',
                '초콜릿 월넛 돔 쿠키',
                '오도독 건강한 넛&블루베리',
                '자일리톨 캔디 크리스탈 레몬',
                '매콤 소시지 불고기 베이크',
                '오가닉 프로틴 그릭 요거트 & 그래놀라',
                '자바 칩 초콜릿 아포가토',
                '트러플 머쉬룸 수프',
                '단호박 에그 샌드위치',
                '리얼 치즈 베이글',
                '가나슈 품은 초콜릿 스콘',
                'The 촉촉 초콜릿 생크림 케이크',
                '블루베리 마카롱',
                '청크 초콜릿 쿠키 틴 세트',
                '크림치즈 브리오슈 보스톡',
                '우리米 카스텔라',
                '콜라겐 레드푸드 쉐이크',
                '크레이프 에멘탈 치즈 케이크',
                '우유 품은 초콜릿 크루아상',
                '로고 코인 밀크 초콜릿 (실버)',
                '하루 한 컵 RED',
                '한 입에 쏙 우리 과일칩(딸기&사과)',
                '로스티드 아몬드 앤 초콜릿',
                '다크 초콜릿 카우보이 쿠키',
                '현미 크림 수프',
                '한입에 쏙 공주 알밤',
                '부드러운 생크림 카스텔라',
                '바비큐 치킨 치즈 치아바타',
                '로고 코인 다크 초콜릿 (골드)',
                '사과 가득 핸디 젤리',
                '할로윈 베어리 위치 카라멜',
                '담백한 플레인 베이글',
                '진한 초콜릿 퍼지 케이크',
                '베어리스타 오가닉 젤리',
                '쉬림프 코코넛 샐러드 밀 박스',
                '트리플 미니 스콘',
                '에그에그 샌드위치',
                '더블 치즈 베이글 칩',
                '헤븐리 티라미수',
                '아몬드 토피넛 캔디',
                '피칸 브라우니',
                '우리 흑米 카스텔라',
                '다크 초콜릿 마카롱',
                '커리 치킨 샐러드 밀 박스',
                '레드벨벳 크림치즈 케이크',
                '할로윈 치즈 마카롱',
                '유산균 옐로푸드 쉐이크',
                '스모크드 소시지 브레드',
                '클라우드 치즈 케이크',
                '한라봉 가득 핸디 젤리',
                '트리플 치즈 크로크무슈',
                '자바 칩 유기농 아이스크림 바닐라',
                '에그 베이컨 브리오슈 밀 박스',
                '할로윈 민트 초콜릿 케이크',
                '바닐라 마카롱',
                '유기농 아이스크림 바닐라',
                '넛츠 초콜릿 아포가토',
                'B.E.L.T. 샌드위치',
                '오렌지 카라멜 데니핀',
                '스트로베리 마카롱',
                '할로윈 흑임자 마카롱',
                '브렉퍼스트 잉글리쉬 머핀',
                '청담스타 오 허니 케이크',
                '하트 파이',
                '7 레이어 가나슈 케이크',
                '올라 쿠바노 샌드위치',
                '라이스 칩(블루베리 잼)',
                '바질 토마토 크림치즈 베이글',
                '촉촉 슈크림 레이어 케이크',
                '미니 클래식 스콘',
                '프로틴 블랙푸드 쉐이크 ',
                '베이컨 치즈 토스트',
                '블루베리 쿠키 치즈 케이크',
                '몽블랑 치즈 케이크',
                '감바스 파스타 밀 박스',
                'New 한 입에 쏙 고구마',
                '뺑 오 쇼콜라',
                '스타벅스 찹쌀말랑',
                '할로윈 베어리 펌킨 카라멜',
                '슈크림 가득 바움쿠헨',
                '청담스타 얼 그레이 밀크 케이크',
                '바닐라 아포가토',
                'New 초콜릿 푸딩',
                '상큼한 딸기 생크림 카스텔라',
                '오가닉 그릭 요거트 플레인',
                '할로윈 펌킨 치즈 케이크',
                '부드러운 티라미수 롤',
                '넛츠 바닐라 아포가토',
                '헤이즐넛 브라우니']

    return beverage, size, syrup, food

def data_maker():

    import itertools
    import random

    data = []
    data_1 = []
    append_1 = data_1.append
    # data_2 = []
    # append_2 = data_2.append
    # data_3 = []
    # append_3 = data_3.append

    beverage, size, syrup, food = slot()

    for bev, siz, sy, fo in itertools.product(beverage, size, syrup, food):
        data.append(f'/beverage;{bev}/ /size;{siz}/사이즈 한 잔에 /syrup;{sy}/ 두 번 넣어주시고 /food;{fo}/ 한 개 주세요.')
        data.append(f'/beverage;{bev}/ 하나 /size;{siz}/로 주시고요 /syrup;{sy}/ 다섯 번에 /food;{fo}/도 하나 주세요.')
    data = random.sample(data, 200000)
    
    for bev in beverage:
        append_1(f'/beverage;{bev} 주세요.')
        append_1(f'/beverage;{bev} 한 잔 주세요.')
        append_1(f'/beverage;{bev}로 주세요.')
        append_1(f'/beverage;{bev} 부탁합니다.')
        append_1(f'/beverage;{bev} 한 잔 부탁합니다.')

    for siz in size:
        append_1(f'/size;{siz}로 주세요.')
        append_1(f'/size;{siz}요.')
        append_1(f'/size;{siz}로 부탁합니다.')
        append_1(f'/size;{siz}로 할게요.')

    for sy in syrup:
        append_1(f'/syrup;{sy} 넣어주세요.')
        append_1(f'/syrup;{sy} 한 번 넣어 주세요.')
        append_1(f'/syrup;{sy} 조금 넣어주세요.')
        append_1(f'/syrup;{sy} 많이 넣어주세요.')
        append_1(f'/syrup;{sy} 부탁합니다.')
        append_1(f'/syrup;{sy} 한 번 부탁합니다.')
        append_1(f'/syrup;{sy} 조금 부탁합니다.')
        append_1(f'/syrup;{sy} 많이 부탁합니다.')

    for fo in food:
        append_1(f'/food;{fo} 주세요.')
        append_1(f'/food;{fo} 하나 주세요.')
        append_1(f'/food;{fo} 한 개 주세요.')
        append_1(f'/food;{fo}로 주세요.')
        append_1(f'/food;{fo} 부탁합니다.')
        append_1(f'/food;{fo} 한 개 부탁합니다.')
        append_1(f'/food;{fo} 하나 부탁합니다.')

    data.extend(data_1)
    
    
    return data

# %% [markdown]
# ### Save to txt file

# %%
import itertools
with open('new_data.txt','a') as f:
    for i in data_maker():
        f.write(f'{i}\n')
